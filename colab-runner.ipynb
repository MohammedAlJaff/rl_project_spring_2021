# %% [markdown]
# # RL project

# %% [markdown]
# ## Mount google drive to save current models ther

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# After the drive is mounted for the first time, go to the files section, go to drive/MyDrive and create an empty folder there called *models*.

# %%
! ls -l
# Out:
# total 48
# -rw-r--r-- 1 root root 1559 May 10 13:30 config.py
# -rw-r--r-- 1 root root 5044 May 10 13:41 dqn.py
# drwx------ 5 root root 4096 May 10 13:43 drive
# -rw-r--r-- 1 root root 3041 May 10 13:30 evaluate.py
# drwxr-xr-x 2 root root 4096 May 10 13:41 __pycache__
# -rw-r--r-- 1 root root   36 May 10 13:30 requirements.txt
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data
# -rw-r--r-- 1 root root  136 May 10 13:29 test.py
# -rw-r--r-- 1 root root 4993 May 10 13:41 train.py
# -rw-r--r-- 1 root root  454 May 10 13:30 utils.py

# %%
 # %xmode
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ## Set up wandb

# %%
# %%capture
# !pip install wandb

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Check if cuda is ther

# %%
! python check-cuda.py
# Out:
# cuda

# %% [markdown]
# ## Start running experiments

# %%
! python train.py --env Pong-v0 --logwandb True
# Out:
# wandb: Currently logged in as: paul-h (use `wandb login --relogin` to force relogin)
# 2021-05-10 14:16:23.822395: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run classic-thunder-1
# wandb: ⭐️ View project at https://wandb.ai/paul-h/reinforcement-learning-pong
# wandb: 🚀 View run at https://wandb.ai/paul-h/reinforcement-learning-pong/runs/1ez1cnzk
# wandb: Run data is saved locally in /content/wandb/run-20210510_141622-1ez1cnzk
# wandb: Run `wandb offline` to turn off syncing.
#
# Episode 0/100000: -21.0
# Best performance so far! Saving model.
# Episode 25/100000: -21.0
# Best performance so far! Saving model.
# Episode 50/100000: -21.0
# Best performance so far! Saving model.
# Episode 75/100000: -21.0
# Best performance so far! Saving model.
# Episode 100/100000: -20.8
# Best performance so far! Saving model.
# Episode 125/100000: -20.8
# ...
